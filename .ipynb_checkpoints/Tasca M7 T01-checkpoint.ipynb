# %% [markdown]
# ## Exercici 1
# **Crea almenys dos models de classificació diferents per intentar predir el millor les classes de l'arxiu adjunt.**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PowerTransformer, MinMaxScaler,RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, confusion_matrix, accuracy_score
from sklearn.metrics import classification_report, roc_curve, plot_confusion_matrix, f1_score, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn import svm
import csv
import lazypredict
from lazypredict.Supervised import LazyRegressor, LazyClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import svm
from sklearn.linear_model import LogisticRegression
import xgboost as xgb

# %%
col_names = ['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines','Proline']
df = pd. read_csv("wineData.txt", sep = ",", names = col_names)
df.head()
# Out:
#    Class  Alcohol  Malic acid  Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71 2.43              15.60        127
# 1      1    13.20        1.78 2.14              11.20        100
# 2      1    13.16        2.36 2.67              18.60        101
# 3      1    14.37        1.95 2.50              16.80        113
# 4      1    13.24        2.59 2.87              21.00        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity  Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64 1.04                          3.92     1065
# 1             4.38 1.05                          3.40     1050
# 2             5.68 1.03                          3.17     1185
# 3             7.80 0.86                          3.45     1480
# 4             4.32 1.04                          2.93      735

# %%
df.describe()
# Out:
#        Class  Alcohol  Malic acid    Ash  Alcalinity of ash  Magnesium  \
# count 178.00   178.00      178.00 178.00             178.00     178.00
# mean    1.94    13.00        2.34   2.37              19.49      99.74
# std     0.78     0.81        1.12   0.27               3.34      14.28
# min     1.00    11.03        0.74   1.36              10.60      70.00
# 25%     1.00    12.36        1.60   2.21              17.20      88.00
# 50%     2.00    13.05        1.87   2.36              19.50      98.00
# 75%     3.00    13.68        3.08   2.56              21.50     107.00
# max     3.00    14.83        5.80   3.23              30.00     162.00
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count         178.00      178.00                178.00           178.00
# mean            2.30        2.03                  0.36             1.59
# std             0.63        1.00                  0.12             0.57
# min             0.98        0.34                  0.13             0.41
# 25%             1.74        1.21                  0.27             1.25
# 50%             2.35        2.13                  0.34             1.56
# 75%             2.80        2.88                  0.44             1.95
# max             3.88        5.08                  0.66             3.58
#
#        Color intensity    Hue  OD280/OD315 of diluted wines  Proline
# count           178.00 178.00                        178.00   178.00
# mean              5.06   0.96                          2.61   746.89
# std               2.32   0.23                          0.71   314.91
# min               1.28   0.48                          1.27   278.00
# 25%               3.22   0.78                          1.94   500.50
# 50%               4.69   0.96                          2.78   673.50
# 75%               6.20   1.12                          3.17   985.00
# max              13.00   1.71                          4.00  1680.00

# %%
df.groupby('Class').mean()
# Out:
#        Alcohol  Malic acid  Ash  Alcalinity of ash  Magnesium  Total phenols  \
# Class
# 1        13.74        2.01 2.46              17.04     106.34           2.84
# 2        12.28        1.93 2.24              20.24      94.55           2.26
# 3        13.15        3.33 2.44              21.42      99.31           1.68
#
#        Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity  \
# Class
# 1            2.98                  0.29             1.90             5.53
# 2            2.08                  0.36             1.63             3.09
# 3            0.78                  0.45             1.15             7.40
#
#        Hue  OD280/OD315 of diluted wines  Proline
# Class
# 1     1.06                          3.16  1115.71
# 2     1.06                          2.79   519.51
# 3     0.68                          1.68   629.90

# %%
df.isnull().sum()
# Out:
# Class                           0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
# matriu de correlació
fig, ax = plt.subplots(figsize=(15, 10))
sns.set_theme(style="white")
matrix = np.triu(df.corr())
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df.corr(), annot=True, mask=matrix, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
#  12  OD280/OD315 of diluted wines  178 non-null    float64
#  13  Proline                       178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
feature =  ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
labels = ['class_0' 'class_1' 'class_2']

# %%
print(labels)
# Out:
# ['class_0class_1class_2']

# %%
 # Matriz
X = df.drop('Class', axis = 'columns')
# Vector
y = df['Class']

# %%
df['Class'].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class, dtype: int64

# %%
sns.countplot(x='Class', data=df)
plt.show()

# %%
#split the dataset into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.3, random_state=0)

# %%
## escalamos los valores

scaler = StandardScaler()

X_train_std=scaler.fit_transform(X_train)
X_test_std=scaler.transform(X_test)

# %%
# LazyClassifier Instance and fiting data

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 45.17it/s]

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LinearSVC                          1.00               1.00    None      1.00
# ExtraTreesClassifier               1.00               1.00    None      1.00
# LogisticRegression                 1.00               1.00    None      1.00
# Perceptron                         1.00               1.00    None      1.00
# QuadraticDiscriminantAnalysis      1.00               1.00    None      1.00
# KNeighborsClassifier               1.00               1.00    None      1.00
# PassiveAggressiveClassifier        1.00               1.00    None      1.00
# NuSVC                              1.00               1.00    None      1.00
# RidgeClassifier                    1.00               1.00    None      1.00
# RidgeClassifierCV                  1.00               1.00    None      1.00
# CalibratedClassifierCV             1.00               1.00    None      1.00
# SVC                                1.00               1.00    None      1.00
# SGDClassifier                      0.98               0.98    None      0.98
# LinearDiscriminantAnalysis         0.98               0.98    None      0.98
# BaggingClassifier                  0.98               0.98    None      0.98
# NearestCentroid                    0.98               0.98    None      0.98
# RandomForestClassifier             0.98               0.98    None      0.98
# LGBMClassifier                     0.96               0.97    None      0.96
# LabelSpreading                     0.94               0.95    None      0.94
# LabelPropagation                   0.94               0.95    None      0.94
# GaussianNB                         0.94               0.95    None      0.94
# DecisionTreeClassifier             0.93               0.93    None      0.93
# BernoulliNB                        0.91               0.92    None      0.91
# AdaBoostClassifier                 0.89               0.90    None      0.89
# ExtraTreeClassifier                0.89               0.88    None      0.89
# DummyClassifier                    0.41               0.33    None      0.24
#
#                                Time Taken
# Model
# LinearSVC                            0.01
# ExtraTreesClassifier                 0.09
# LogisticRegression                   0.01
# Perceptron                           0.01
# QuadraticDiscriminantAnalysis        0.01
# KNeighborsClassifier                 0.01
# PassiveAggressiveClassifier          0.01
# NuSVC                                0.01
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.01
# CalibratedClassifierCV               0.03
# SVC                                  0.01
# SGDClassifier                        0.01
# LinearDiscriminantAnalysis           0.01
# BaggingClassifier                    0.02
# NearestCentroid                      0.01
# RandomForestClassifier               0.12
# LGBMClassifier                       0.07
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# GaussianNB                           0.01
# DecisionTreeClassifier               0.01
# BernoulliNB                          0.01
# AdaBoostClassifier                   0.08
# ExtraTreeClassifier                  0.01
# DummyClassifier                      0.01

# %%
print("Training set - Features: ", X_train.shape, "Target: ", y_train.shape)
print("Test set - Features: ", X_test.shape, "Target: ",y_test.shape)
# Out:
# Training set - Features:  (124, 13) Target:  (124,)
# Test set - Features:  (54, 13) Target:  (54,)

# %%
# Decision Tree
model1 = DecisionTreeClassifier(criterion='gini', splitter='random')
model1 = model1.fit(X_train,y_train)
y_pred1 = model1.predict(X_test)

# %%
#K-Nearest Neighbors classifier
model2 = KNeighborsClassifier()
model2.fit(X_train, y_train)
y_pred2 = model2.predict(X_test)

# %%
#logistic regressión
model4 = LogisticRegression()
model4.fit(X_train,y_train)
y_pred4 = model4.predict(X_test)

# %%
#Support vector machine classifier
model3 = svm.SVC()
model3.fit(X_train, y_train)
y_pred3 = model3.predict(X_test)

# %% [markdown]
# ## Exercici 2
# **Compara els models de classificació utilitzant la precisió (accuracy), una matriu de confusió i d’altres mètriques més avançades.**

# %%
print('Accuracy decision tree model:',round(metrics.accuracy_score(y_test, y_pred1),2)*100,'%')
print('Accuracy KNN model:',round(metrics.accuracy_score(y_test, y_pred2),2)*100,'%')
print('Accuracy SVM model:',round(metrics.accuracy_score(y_test, y_pred3),2)*100,'%')
print('Accuracy Logistic model:',round(metrics.accuracy_score(y_test, y_pred4),2)*100,'%')
# Out:
# Accuracy decision tree model: 93.0 %
# Accuracy KNN model: 72.0 %
# Accuracy SVM model: 78.0 %
# Accuracy Logistic model: 94.0 %

# %%
m1 = metrics.confusion_matrix(y_test, y_pred1)
m2 = metrics.confusion_matrix(y_test, y_pred2)
m3 = metrics.confusion_matrix(y_test, y_pred3)
m4 = metrics.confusion_matrix(y_test, y_pred4)


print('Matrix decision tree model:',m1)
print('Matrix KNN model:',m2)
print('Matrix SVM model:',m3)
print('Matrix model:',m4)
# Out:
# Matrix decision tree model: [[19  0  0]
#  [ 2 19  1]
#  [ 0  1 12]]
# Matrix KNN model: [[16  1  2]
#  [ 1 17  4]
#  [ 3  4  6]]
# Matrix SVM model: [[17  0  2]
#  [ 1 20  1]
#  [ 1  7  5]]
# Matrix model: [[17  2  0]
#  [ 0 21  1]
#  [ 0  0 13]]

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap


dicc = {'DT': m1, 'KNN': m2, 'SVM': m3, 'Logistic': m4}

model = dicc.keys()

for m in model:
    sns.heatmap(pd.DataFrame(dicc[m]), annot=True, cmap="YlGnBu" ,fmt='g')
    ax.xaxis.set_label_position("top")
    plt.tight_layout()
    plt.title(m, y=1.1,fontsize = 15)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
#sensitivity TP / (TP + FN)
s1 = m1[1,1] / (m1[1,1] + m1[1,0])
s2 = m2[1,1] / (m2[1,1] + m2[1,0])
s3 = m3[1,1] / (m3[1,1] + m3[1,0])
s4 = m4[1,1] / (m4[1,1] + m4[1,0])

print('Sensitivity decision tree model:',s1)
print('Sensitivity KNN model:',s2)
print('Sensitivity SVM model:',s3)
print('Sensitivity Logistic model:',s4)
# Out:
# Sensitivity decision tree model: 0.9047619047619048
# Sensitivity KNN model: 0.9444444444444444
# Sensitivity SVM model: 0.9523809523809523
# Sensitivity Logistic model: 1.0

# %% [markdown]
# ## Exercici 3
# **Entrena’ls usant els diferents paràmetres que admeten per tal de millorar-ne la predicció.**

# %%
# Decision Tree
model6 = DecisionTreeClassifier(criterion='entropy', splitter='best')
model6 = model6.fit(X_train,y_train)
y_pred6 = model6.predict(X_test)

# %%
# K-Nearest Neighbors classifie
model7 = KNeighborsClassifier(n_neighbors=1, weights='distance',leaf_size=50)
model7.fit(X_train, y_train)
y_pred7 = model7.predict(X_test)

# %%
# Support vector machine classifier
model8 = svm.SVC(kernel='poly',degree=3, coef0=1.0, C=5)# porbablemete c5
model8.fit(X_train, y_train)
y_pred8 = model8.predict(X_test)

# %%
# Logistic classifier
model9 = LogisticRegression(class_weight='balanced',solver= 'newton-cg', multi_class='multinomial', random_state=42)
model9.fit(X_train,y_train)
y_pred9 = model9.predict(X_test)

# %% [markdown]
# ## Exercici 4
# **Compara el seu rendiment fent servir l’aproximació traint/test o cross-validation.**

# %%
#Cross-validation
cv = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

scores1 = cross_val_score(model1, X_test, y_test, cv=cv)
scores2 = cross_val_score(model2, X_test, y_test, cv=cv)
scores3 = cross_val_score(model3, X_test, y_test, cv=cv)
scores4 = cross_val_score(model4, X_test, y_test, cv=cv)


print(" Decision tree classifier has %0.2f accuracy with a standard deviation of %0.2f" % (scores1.mean(), scores1.std()))
print(" KNN classifier has %0.2f accuracy with a standard deviation of %0.2f" % (scores2.mean(), scores2.std()))
print(" SVM classifier has %0.2f accuracy with a standard deviation of %0.2f" % (scores3.mean(), scores3.std()))
print(" Logistic classifier has %0.2f accuracy with a standard deviation of %0.2f" % (scores4.mean(), scores4.std()))
# Out:
#  Decision tree classifier has 0.87 accuracy with a standard deviation of 0.09
#  KNN classifier has 0.69 accuracy with a standard deviation of 0.09
#  SVM classifier has 0.72 accuracy with a standard deviation of 0.01
#  Logistic classifier has 0.89 accuracy with a standard deviation of 0.07

# %%
#Cross-validation
cv = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

scores6 = cross_val_score(model6, X_test, y_test, cv=cv)
scores7 = cross_val_score(model7, X_test, y_test, cv=cv)
scores8 = cross_val_score(model8, X_test, y_test, cv=cv)
scores9 = cross_val_score(model9, X_test, y_test, cv=cv)


print(" Decision tree classifier has %0.2f accuracy with a standard deviation of %0.2f" % (scores6.mean(), scores1.std()))
print(" KNN classifier has %0.2f accuracy with a standard deviation of %0.2f" % (scores7.mean(), scores2.std()))
print(" SVM classifier has %0.2f accuracy with a standard deviation of %0.2f" % (scores8.mean(), scores3.std()))
print(" Logistic classifier has %0.2f accuracy with a standard deviation of %0.2f" % (scores9.mean(), scores4.std()))
# Out:
#  Decision tree classifier has 0.85 accuracy with a standard deviation of 0.09
#  KNN classifier has 0.63 accuracy with a standard deviation of 0.09
#  SVM classifier has 0.76 accuracy with a standard deviation of 0.01
#  Logistic classifier has 0.93 accuracy with a standard deviation of 0.07

# %% [markdown]
# ## Exercici 5
# **Aplica algun procés d'enginyeria per millorar els resultats (normalització, estandardització, mostreig...**

# %%
fig = sns.boxplot(data=df, orient="h", palette="Set2")

# %%
#eliminate outliers from Q1 and Q3 - 0.25 0.75
Q1 = df.quantile(q=0.25)
Q3 = df.quantile(q=0.75)
print(Q1, Q3)
IQR = df.apply(stats.iqr)
# Out:
# Class                            1.00
# Alcohol                         12.36
# Malic acid                       1.60
# Ash                              2.21
# Alcalinity of ash               17.20
# Magnesium                       88.00
# Total phenols                    1.74
# Flavanoids                       1.21
# Nonflavanoid phenols             0.27
# Proanthocyanins                  1.25
# Color intensity                  3.22
# Hue                              0.78
# OD280/OD315 of diluted wines     1.94
# Proline                        500.50
# Name: 0.25, dtype: float64 Class                            3.00
# Alcohol                         13.68
# Malic acid                       3.08
# Ash                              2.56
# Alcalinity of ash               21.50
# Magnesium                      107.00
# Total phenols                    2.80
# Flavanoids                       2.88
# Nonflavanoid phenols             0.44
# Proanthocyanins                  1.95
# Color intensity                  6.20
# Hue                              1.12
# OD280/OD315 of diluted wines     3.17
# Proline                        985.00
# Name: 0.75, dtype: float64

# %%
# Solo mantenemos filas que esten dentro de 1.5*IQR de Q1 y Q3
data_clean = df[~((df < (Q1-1.5*IQR)) | (df > (Q3+1.5*IQR))).any(axis=1)]
# Calculamos cuantas filas desaparecerian
data_clean.shape
# Out:
# (161, 14)

# %% [markdown]
# *Solo quedan 161 de 178 filas*

# %%
fig = sns.boxplot(data=df_minmax, orient="h", palette="Set2")

# %%
X1 = df_minmax.drop('Class',axis=1)
y1 = df_minmax['Class']
#Train 70%, test 30%
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.3, random_state=42)

# %%
print(X_train.shape,y_train.shape, X_test.shape, y_test.shape)
# Out:
# (124, 13) (124,) (54, 13) (54,)

# %%
#scaling the values
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model11 = DecisionTreeClassifier(criterion='entropy', splitter='best')
model11 = model11.fit(X_train,y_train)
y_pred11 = model11.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21424\911956916.py in <module>
#       1 model11 = DecisionTreeClassifier(criterion='entropy', splitter='best')
# ----> 2 model11 = model11.fit(X_train,y_train)
#       3 y_pred11 = model11.predict(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     201
#     202         if is_classification:
# --> 203             check_classification_targets(y)
#     204             y = np.copy(y)
#     205
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     195         "multilabel-sequences",
#     196     ]:
# --> 197         raise ValueError("Unknown label type: %r" % y_type)
#     198
#     199
#
# ValueError: Unknown label type: 'continuous'
